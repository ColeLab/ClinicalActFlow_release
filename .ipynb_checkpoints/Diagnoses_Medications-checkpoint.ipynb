# %% [markdown]
# # Diagnoses and Medications
# Lists / prints out a bunch of information regarding medications and diagnoses

# %%
import numpy as np
import pandas as pd
import json

# subjects
subj_df = pd.read_csv('subject_list.txt', sep='\t', index_col = 0, header = 0)

# %%
phenotype_dir = '/projects/f_mc1689_1/ClinicalActFlow/data/ds000030_R105/phenotype/'

# load in dataframes
scid = pd.read_csv(phenotype_dir+'phenotype_scid.tsv',delimiter='\t')
meds = pd.read_csv(phenotype_dir+'phenotype_medication.tsv',delimiter='\t')

#load in metadata
med_dict = pd.read_csv('Medication_dict.csv')

# %%
df_out = pd.DataFrame(columns=['subj','primary_diagnosis','secondary_diagnosis'])
n_subj = len(subj_df[subj_df['group']=='SCHZ'].index)
for subj in subj_df[subj_df['group']=='SCHZ'].index:
    
    data = scid[scid['participant_id']==subj]
    df = pd.DataFrame(columns=['subj','primary_diagnosis','secondary_diagnosis'])
    df['primary_diagnosis'] = data['scid_dx1']
    df['secondary_diagnosis'] = data['scid_dx2']
    df['subj'] = subj
    df_out = pd.concat([df_out,df])
print('Primary Diag:')
print(df_out['primary_diagnosis'].value_counts())
print(df_out['primary_diagnosis'].value_counts() / n_subj*100)
print('')
print('Secondary Diag:')
print(df_out['secondary_diagnosis'].value_counts())
print(df_out['secondary_diagnosis'].value_counts() / n_subj*100)
# Out:
# Primary Diag:
# 295.30 Schizophrenia, Paranoid Type            16
# 295.70 Schizoaffective Disorder                 9
# 295.90 Schizophrenia, Undifferentiated Type     6
# 295.60 Schizophrenia, Residual Type             4
# 295.10 Schizophrenia, Disorganized Type         1
# Name: primary_diagnosis, dtype: int64
# 295.30 Schizophrenia, Paranoid Type            44.444444
# 295.70 Schizoaffective Disorder                25.000000
# 295.90 Schizophrenia, Undifferentiated Type    16.666667
# 295.60 Schizophrenia, Residual Type            11.111111
# 295.10 Schizophrenia, Disorganized Type         2.777778
# Name: primary_diagnosis, dtype: float64
#
# Secondary Diag:
# 311  Depressive Disorder NOS                                                                 9
# 303.90 Alcohol Dependence                                                                    8
# 314.01 Attention-Deficit/Hyperactivity Disorder, Combined Type                               3
# 314.00 Attention-Deficit/Hyperactivity Disorder, Predominantly Inattentive Type              3
# 296.80 Bipolar Disorder NOS                                                                  2
# 305.20 Cannabis Abuse                                                                        2
# 305.00 Alcohol Abuse                                                                         1
# 314.01 Attention-Deficit/Hyperactivity Disorder, Predominantly Hyperactive-Impulsive Type    1
# Name: secondary_diagnosis, dtype: int64
# 311  Depressive Disorder NOS                                                                 25.000000
# 303.90 Alcohol Dependence                                                                    22.222222
# 314.01 Attention-Deficit/Hyperactivity Disorder, Combined Type                                8.333333
# 314.00 Attention-Deficit/Hyperactivity Disorder, Predominantly Inattentive Type               8.333333
# 296.80 Bipolar Disorder NOS                                                                   5.555556
# 305.20 Cannabis Abuse                                                                         5.555556
# 305.00 Alcohol Abuse                                                                          2.777778
# 314.01 Attention-Deficit/Hyperactivity Disorder, Predominantly Hyperactive-Impulsive Type     2.777778
# Name: secondary_diagnosis, dtype: float64

# %%
df_out = pd.DataFrame(columns=['subj','med_name','med_class'])
df_ind = pd.DataFrame(columns=['subj','use','Antipsychotic','SHA','Antidepressant','Mood stabilizer','Other','Stimulant'])
for subj in subj_df[subj_df['group']=='SCHZ'].index:
    df_ind1 = pd.DataFrame()
    df_ind1['subj'] = [subj]
    count=0
    
    data = meds[meds['participant_id']==subj]
    for i in range(1,21):
        if data['med_use'+str(i)].values==1:
            df = pd.DataFrame()
            med_name = data['med_name'+str(i)].values[0]
            med_class = med_dict['Class'][med_dict['Drug'] == med_name].values[0]
            
            df['med_name'] = [med_name]
            df['med_class'] = [med_class]
            df['subj'] = [subj]
            df_out = pd.concat([df_out,df],sort=False)
            
            # apply to individual data
            count = count+1
            df_ind1[med_class] = [1]
                   
    df_ind1['use'] = [count]
    df_ind = pd.concat([df_ind,df_ind1],sort=False)

display(df_out.head())
display(df_ind.head())
# Out:
#         subj                med_name      med_class
# 0  sub-50007  Risperdal/ Risperidone  Antipsychotic
# 0  sub-50007  Artane/Trihexyphenidyl          Other
# 0  sub-50008   Abilify/ Aripiprazole  Antipsychotic
# 0  sub-50013     Zyprexa/ Olanzapine  Antipsychotic
# 0  sub-50013     Restoril/ Temazepam            SHA
#         subj use Antipsychotic  SHA Antidepressant Mood stabilizer Other  \
# 0  sub-50007   2             1  NaN            NaN             NaN     1
# 0  sub-50008   1             1  NaN            NaN             NaN   NaN
# 0  sub-50013   3             1    1            NaN             NaN   NaN
# 0  sub-50014   2             1  NaN            NaN             NaN     1
# 0  sub-50015   1             1  NaN            NaN             NaN   NaN
#
#   Stimulant
# 0       NaN
# 0       NaN
# 0       NaN
# 0       NaN
# 0       NaN

# %%
for med_class in ['Antipsychotic','SHA','Antidepressant','Mood stabilizer','Other','Stimulant']:
    print(df_ind[med_class].value_counts())
# Out:
# 1    31
# Name: Antipsychotic, dtype: int64
# 1    11
# Name: SHA, dtype: int64
# 1    14
# Name: Antidepressant, dtype: int64
# 1    7
# Name: Mood stabilizer, dtype: int64
# 1    5
# Name: Other, dtype: int64
# 1    1
# Name: Stimulant, dtype: int64

# %%
print(df_out['med_class'].value_counts())
# Out:
#           subj                                   med_name
# 133  sub-50007                     Risperdal/ Risperidone
# 133  sub-50007                     Artane/Trihexyphenidyl
# 134  sub-50008                      Abilify/ Aripiprazole
# 136  sub-50013                        Zyprexa/ Olanzapine
# 136  sub-50013                        Restoril/ Temazepam
# 136  sub-50013                          Ativan/ Lorazepam
# 137  sub-50014                      Abilify/ Aripiprazole
# 137  sub-50014                      Cogentin/ Benztropine
# 138  sub-50015                      Abilify/ Aripiprazole
# 141  sub-50021                        Geodon/ Ziprasidone
# 141  sub-50021                       Klonopin/ Clonazepam
# 141  sub-50021                          Ativan/ Lorazepam
# 141  sub-50021                       Remeron/ Mirtazapine
# 141  sub-50021                      Lamictal/ Lamotrigine
# 142  sub-50022                          Fluoxetine/Prozac
# 142  sub-50022                     Artane/Trihexyphenidyl
# 142  sub-50022                          Lorazepam/ Ativan
# 142  sub-50022                      Invega / Paliperidone
# 142  sub-50022                                    Rozerem
# 143  sub-50023              Risperidone/ Risperdal Consta
# 143  sub-50023                          Paxil/ Paroxetine
# 143  sub-50023                 Sleep Eze/ Diphenhydramine
# 143  sub-50023                  Phentermine Hydrochloride
# 144  sub-50025                        Zyprexa/ Olanzapine
# 145  sub-50027                        Clozaril/ Clozapine
# 148  sub-50033                     Risperdal/ Risperidone
# 149  sub-50034                       Seroquel/ Quetiapine
# 151  sub-50036                       Seroquel/ Quetiapine
# 151  sub-50036                       Clonazepam/ Klonopin
# 151  sub-50036                        Topamax/ Topiramate
# ..         ...                                        ...
# 163  sub-50056                        Geodon/ Ziprasidone
# 163  sub-50056                       Seroquel/ Quetiapine
# 163  sub-50056                         Celexa/ Citalopram
# 164  sub-50058  Lithium Carbonate/Eskalith/Lithonate/ etc
# 164  sub-50058                         Prozac/ Fluoxetine
# 164  sub-50058                      Risperidone/Risperdal
# 166  sub-50060                       Depakote/ Divalproex
# 166  sub-50060                     Risperdal/ Risperidone
# 166  sub-50060                          Lorazepam/ Ativan
# 166  sub-50060                         Prozac/ Fluoxetine
# 168  sub-50064                         Trazodone/ Desyrel
# 168  sub-50064                    Divalproex/ Depakote ER
# 168  sub-50064                      Lamictal/ Lamotrigine
# 169  sub-50066                       Seroquel/ Quetiapine
# 169  sub-50066                   Wellbutrin SR /Bupropion
# 171  sub-50069                         Prozac/ Fluoxetine
# 171  sub-50069                      Abilify/ Aripiprazole
# 171  sub-50069                           Ambien/ Zolpidem
# 176  sub-50080  Lithium Carbonate/Eskalith/Lithonate/ etc
# 176  sub-50080                         Loxitane/ Loxapine
# 176  sub-50080                       Seroquel/ Quetiapine
# 176  sub-50080                        Temazepam/ Restoril
# 177  sub-50081                       Seroquel/ Quetiapine
# 178  sub-50083                        Geodon/ Ziprasidone
# 178  sub-50083                     Prolixin/ Fluphenazine
# 178  sub-50083                        Navane/ Thiothixene
# 178  sub-50083                       Klonopin/ Clonazepam
# 178  sub-50083                       Wellbutrin/Bupropion
# 179  sub-50085                     Risperdal/ Risperidone
# 179  sub-50085              Lexapro/ Escitalopram oxalate
#
# [78 rows x 2 columns]
